# %%
#Used for making HTTP requests to the URLs.
import requests

#The BeautifulSoup library is used for parsing HTML and XML documents, making it easier to extract data from them.
from bs4 import BeautifulSoup

#Used for analysing, cleaning, exploring and manipulating data.
import pandas as pd

# %%
#Fetching the HTML content from the website.
html_text = requests.get("https://m.cricbuzz.com/cricket-series/apps/ipl-2022/auction/teams/58#top").text

#soup object helps search and navigate through the html structure.
soup = BeautifulSoup(html_text, 'lxml')

#Capturing the entire div block.
player_cards = soup.find_all('div', class_ = "list-group-item")

#Creating an empty list named 'data'.
data = []

#For Loop to collect all the player name, their role, country, price for which they were bought and their status.
for player_card in player_cards:
    player_name = player_card.find('h3', class_ = "cb-list-heading").text
    specialist = player_card.p.get_text(strip=True).split('•')[0].strip()
    country = player_card.p.get_text(strip=True).split('•')[1].strip()
    
    price = player_card.find('div', class_ = "col-xs-4 cb-col-text-container text-center").text.replace('RETAINED', '')
    #if price is not None:
    #    price_text = price.get_text().title()
    #else:
    #    price_text = ""
    
    status = player_card.find('div', class_ = "badge bg-rtm")
    
    #As the status is in a badge format, we try to get only the text from it and replace the ones without a status to 'Released'.
    if status is not None:
        status_text = status.get_text().title()
    else:
        status_text = "Released"
    
    #Add the data to the table one after the other.
    data.append({"Players": player_name ,"Specialist": specialist ,"Country": country ,"Final Price": price, "Status": status_text})

#Creating a DataFrame 'df' and styling the table.
df = pd.DataFrame(data)
df.index = range(1, len(df) + 1)
styled_df = df.style.set_properties(**{'text-align': 'left'})
styled_df.set_table_styles([{
    'selector': 'th',
    'props': [('text-align', 'left')]
}])

styled_df
# Out:
# <style type="text/css">
# #T_e9d7e th {
#   text-align: left;
# }
# #T_e9d7e_row0_col0, #T_e9d7e_row0_col1, #T_e9d7e_row0_col2, #T_e9d7e_row0_col3, #T_e9d7e_row0_col4, #T_e9d7e_row1_col0, #T_e9d7e_row1_col1, #T_e9d7e_row1_col2, #T_e9d7e_row1_col3, #T_e9d7e_row1_col4, #T_e9d7e_row2_col0, #T_e9d7e_row2_col1, #T_e9d7e_row2_col2, #T_e9d7e_row2_col3, #T_e9d7e_row2_col4, #T_e9d7e_row3_col0, #T_e9d7e_row3_col1, #T_e9d7e_row3_col2, #T_e9d7e_row3_col3, #T_e9d7e_row3_col4, #T_e9d7e_row4_col0, #T_e9d7e_row4_col1, #T_e9d7e_row4_col2, #T_e9d7e_row4_col3, #T_e9d7e_row4_col4, #T_e9d7e_row5_col0, #T_e9d7e_row5_col1, #T_e9d7e_row5_col2, #T_e9d7e_row5_col3, #T_e9d7e_row5_col4, #T_e9d7e_row6_col0, #T_e9d7e_row6_col1, #T_e9d7e_row6_col2, #T_e9d7e_row6_col3, #T_e9d7e_row6_col4, #T_e9d7e_row7_col0, #T_e9d7e_row7_col1, #T_e9d7e_row7_col2, #T_e9d7e_row7_col3, #T_e9d7e_row7_col4, #T_e9d7e_row8_col0, #T_e9d7e_row8_col1, #T_e9d7e_row8_col2, #T_e9d7e_row8_col3, #T_e9d7e_row8_col4, #T_e9d7e_row9_col0, #T_e9d7e_row9_col1, #T_e9d7e_row9_col2, #T_e9d7e_row9_col3, #T_e9d7e_row9_col4, #T_e9d7e_row10_col0, #T_e9d7e_row10_col1, #T_e9d7e_row10_col2, #T_e9d7e_row10_col3, #T_e9d7e_row10_col4, #T_e9d7e_row11_col0, #T_e9d7e_row11_col1, #T_e9d7e_row11_col2, #T_e9d7e_row11_col3, #T_e9d7e_row11_col4, #T_e9d7e_row12_col0, #T_e9d7e_row12_col1, #T_e9d7e_row12_col2, #T_e9d7e_row12_col3, #T_e9d7e_row12_col4, #T_e9d7e_row13_col0, #T_e9d7e_row13_col1, #T_e9d7e_row13_col2, #T_e9d7e_row13_col3, #T_e9d7e_row13_col4, #T_e9d7e_row14_col0, #T_e9d7e_row14_col1, #T_e9d7e_row14_col2, #T_e9d7e_row14_col3, #T_e9d7e_row14_col4, #T_e9d7e_row15_col0, #T_e9d7e_row15_col1, #T_e9d7e_row15_col2, #T_e9d7e_row15_col3, #T_e9d7e_row15_col4, #T_e9d7e_row16_col0, #T_e9d7e_row16_col1, #T_e9d7e_row16_col2, #T_e9d7e_row16_col3, #T_e9d7e_row16_col4, #T_e9d7e_row17_col0, #T_e9d7e_row17_col1, #T_e9d7e_row17_col2, #T_e9d7e_row17_col3, #T_e9d7e_row17_col4, #T_e9d7e_row18_col0, #T_e9d7e_row18_col1, #T_e9d7e_row18_col2, #T_e9d7e_row18_col3, #T_e9d7e_row18_col4, #T_e9d7e_row19_col0, #T_e9d7e_row19_col1, #T_e9d7e_row19_col2, #T_e9d7e_row19_col3, #T_e9d7e_row19_col4, #T_e9d7e_row20_col0, #T_e9d7e_row20_col1, #T_e9d7e_row20_col2, #T_e9d7e_row20_col3, #T_e9d7e_row20_col4, #T_e9d7e_row21_col0, #T_e9d7e_row21_col1, #T_e9d7e_row21_col2, #T_e9d7e_row21_col3, #T_e9d7e_row21_col4, #T_e9d7e_row22_col0, #T_e9d7e_row22_col1, #T_e9d7e_row22_col2, #T_e9d7e_row22_col3, #T_e9d7e_row22_col4, #T_e9d7e_row23_col0, #T_e9d7e_row23_col1, #T_e9d7e_row23_col2, #T_e9d7e_row23_col3, #T_e9d7e_row23_col4, #T_e9d7e_row24_col0, #T_e9d7e_row24_col1, #T_e9d7e_row24_col2, #T_e9d7e_row24_col3, #T_e9d7e_row24_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_e9d7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9d7e_level0_col0" class="col_heading level0 col0" >Players</th>
#       <th id="T_e9d7e_level0_col1" class="col_heading level0 col1" >Specialist</th>
#       <th id="T_e9d7e_level0_col2" class="col_heading level0 col2" >Country</th>
#       <th id="T_e9d7e_level0_col3" class="col_heading level0 col3" >Final Price</th>
#       <th id="T_e9d7e_level0_col4" class="col_heading level0 col4" >Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9d7e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e9d7e_row0_col0" class="data row0 col0" >Ravindra Jadeja</td>
#       <td id="T_e9d7e_row0_col1" class="data row0 col1" >Allrounder</td>
#       <td id="T_e9d7e_row0_col2" class="data row0 col2" >India</td>
#       <td id="T_e9d7e_row0_col3" class="data row0 col3" >	16.00  Crore    </td>
#       <td id="T_e9d7e_row0_col4" class="data row0 col4" > Retained </td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e9d7e_row1_col0" class="data row1 col0" >Mitchell Santner</td>
#       <td id="T_e9d7e_row1_col1" class="data row1 col1" >Allrounder</td>
#       <td id="T_e9d7e_row1_col2" class="data row1 col2" >New Zealand</td>
#       <td id="T_e9d7e_row1_col3" class="data row1 col3" >	1.90  Crore    </td>
#       <td id="T_e9d7e_row1_col4" class="data row1 col4" > Retained </td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e9d7e_row2_col0" class="data row2 col0" >Moeen Ali</td>
#       <td id="T_e9d7e_row2_col1" class="data row2 col1" >Allrounder</td>
#       <td id="T_e9d7e_row2_col2" class="data row2 col2" >England</td>
#       <td id="T_e9d7e_row2_col3" class="data row2 col3" >	8.00  Crore    </td>
#       <td id="T_e9d7e_row2_col4" class="data row2 col4" > Retained </td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e9d7e_row3_col0" class="data row3 col0" >Ajay Jadav Mandal</td>
#       <td id="T_e9d7e_row3_col1" class="data row3 col1" >Allrounder</td>
#       <td id="T_e9d7e_row3_col2" class="data row3 col2" >India</td>
#       <td id="T_e9d7e_row3_col3" class="data row3 col3" >	20.00  Lakh </td>
#       <td id="T_e9d7e_row3_col4" class="data row3 col4" >Released</td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e9d7e_row4_col0" class="data row4 col0" >Dwaine Pretorius</td>
#       <td id="T_e9d7e_row4_col1" class="data row4 col1" >Allrounder</td>
#       <td id="T_e9d7e_row4_col2" class="data row4 col2" >South Africa</td>
#       <td id="T_e9d7e_row4_col3" class="data row4 col3" >	50.00  Lakh    </td>
#       <td id="T_e9d7e_row4_col4" class="data row4 col4" > Retained </td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e9d7e_row5_col0" class="data row5 col0" >Nishant Sindhu</td>
#       <td id="T_e9d7e_row5_col1" class="data row5 col1" >Allrounder</td>
#       <td id="T_e9d7e_row5_col2" class="data row5 col2" >India</td>
#       <td id="T_e9d7e_row5_col3" class="data row5 col3" >	60.00  Lakh </td>
#       <td id="T_e9d7e_row5_col4" class="data row5 col4" >Released</td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e9d7e_row6_col0" class="data row6 col0" >Shivam Dube</td>
#       <td id="T_e9d7e_row6_col1" class="data row6 col1" >Allrounder</td>
#       <td id="T_e9d7e_row6_col2" class="data row6 col2" >India</td>
#       <td id="T_e9d7e_row6_col3" class="data row6 col3" >	4.00  Crore    </td>
#       <td id="T_e9d7e_row6_col4" class="data row6 col4" > Retained </td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_e9d7e_row7_col0" class="data row7 col0" >Ben Stokes</td>
#       <td id="T_e9d7e_row7_col1" class="data row7 col1" >Allrounder</td>
#       <td id="T_e9d7e_row7_col2" class="data row7 col2" >England</td>
#       <td id="T_e9d7e_row7_col3" class="data row7 col3" >	16.25  Crore </td>
#       <td id="T_e9d7e_row7_col4" class="data row7 col4" >Released</td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_e9d7e_row8_col0" class="data row8 col0" >Bhagath Varma</td>
#       <td id="T_e9d7e_row8_col1" class="data row8 col1" >Allrounder</td>
#       <td id="T_e9d7e_row8_col2" class="data row8 col2" >India</td>
#       <td id="T_e9d7e_row8_col3" class="data row8 col3" >	20.00  Lakh </td>
#       <td id="T_e9d7e_row8_col4" class="data row8 col4" >Released</td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_e9d7e_row9_col0" class="data row9 col0" >Kyle Jamieson</td>
#       <td id="T_e9d7e_row9_col1" class="data row9 col1" >Allrounder</td>
#       <td id="T_e9d7e_row9_col2" class="data row9 col2" >New Zealand</td>
#       <td id="T_e9d7e_row9_col3" class="data row9 col3" >	1.00  Crore </td>
#       <td id="T_e9d7e_row9_col4" class="data row9 col4" >Released</td>
#     </tr>
#     <tr>
#       <th id="T_e9d7e_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_e9d7e_row10_col0" class="data row10 col0" >Ruturaj Gaikwad</td>
